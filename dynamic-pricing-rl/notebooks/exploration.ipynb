# %% [markdown]
# # Exploration
# This notebook explores the pricing environment and demand model.

# %%
from src.environment import PricingEnvironment
env = PricingEnvironment()
obs = env.reset()
print('Initial observation:', obs)
_, rev, _, info = env.step(1)
print('Step revenue:', rev, 'info:', info)
